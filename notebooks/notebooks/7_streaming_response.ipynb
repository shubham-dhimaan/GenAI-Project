# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import ChatOpenAI

# %%
llm  = ChatOpenAI(model = 'gpt-4o')

for chunk in llm.stream("Tell me how quantum copmuting can transform the world of AI in simple words"):
    print(chunk.content, end = "", flush = True)
# Out:
# Quantum computing has the potential to revolutionize the world of AI by dramatically increasing the speed and efficiency of data processing. Here's how it might transform AI:
#
# 1. **Speed**: Quantum computers can process complex calculations much faster than classical computers. This means AI algorithms could be trained and run at significantly higher speeds, leading to quicker results.
#
# 2. **Complex Problem Solving**: Quantum computers excel at solving complex problems that are currently infeasible for classical computers. This could enable AI to tackle more intricate tasks and make more sophisticated predictions.
#
# 3. **Optimization**: Many AI tasks involve optimizing certain parameters. Quantum computing can improve optimization processes, potentially leading to AI systems that are more accurate and reliable.
#
# 4. **Big Data Handling**: Quantum computers could manage and analyze large datasets much more efficiently, enabling AI to extract insights from vast amounts of data.
#
# 5. **Innovation in AI Models**: Quantum computing could lead to the development of new AI models and architectures that are currently unimaginable, significantly expanding AI capabilities.
#
# In simple terms, quantum computing can enhance AI by making it faster, smarter, and capable of handling more complex tasks.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

question = "Can you explain what GenAI is"
response = llm.stream(question)

for chunk in response:
    print(chunk.content, end = "")
# Out:
# **Generative AI (GenAI)** is a branch of artificial intelligence that focuses on creating new content—text, images, audio, video, code, and more—rather than just recognizing or classifying existing data. In other words, GenAI systems learn the underlying patterns of a dataset and then use that knowledge to produce novel, plausible outputs that were never explicitly seen during training.
#
# ---
#
# ## Core Concepts
#
# | Concept | What it is | How it works |
# |---------|------------|--------------|
# | **Generative Models** | Algorithms that learn a probability distribution over data and can sample from it. | They are trained to minimize the difference between real data and synthetic data they generate. |
# | **Transformer Architecture** | A neural network design that excels at sequence modeling (text, audio, etc.). | Uses self‑attention to capture long‑range dependencies, enabling fluent text, coherent stories, or realistic images. |
# | **Diffusion Models** | Generative models that iteratively refine random noise into a coherent image or audio signal. | Start with pure noise and progressively denoise it using a learned reverse diffusion process. |
# | **Variational Autoencoders (VAEs)** | Models that encode data into a latent space and decode it back. | They learn a compressed representation, allowing controlled generation by sampling from the latent space. |
# | **GANs (Generative Adversarial Networks)** | Two networks (generator + discriminator) trained in opposition. | The generator creates samples; the discriminator judges them, driving the generator toward realism. |
#
# ---
#
# ## How Generative AI Works (Simplified)
#
# 1. **Data Collection**
#    Gather a large, diverse dataset (e.g., books, articles, photos, audio recordings).
#
# 2. **Pre‑training**
#    Train a model to predict missing parts of the data.
#    - *Text*: predict the next word or fill in a blank.
#    - *Images*: predict missing pixels or reconstruct images.
#    - *Audio*: predict next samples or reconstruct spectrograms.
#
# 3. **Fine‑tuning (Optional)**
#    Adapt the pre‑trained model to a specific domain or style (e.g., medical reports, legal contracts, anime art).
#
# 4. **Generation**
#    Provide a prompt or seed (text, sketch, noise) and let the model produce new content that follows the learned patterns.
#
# 5. **Post‑processing**
#    Clean up artifacts, adjust style, or combine multiple outputs (e.g., text + image) into a final product.
#
# ---
#
# ## Common Generative AI Models
#
# | Model | Domain | Notable Example |
# |-------|--------|-----------------|
# | GPT‑4, GPT‑4‑Turbo | Text | ChatGPT, AI writing assistants |
# | DALL‑E 3 | Images | AI‑generated illustrations from text prompts |
# | Stable Diffusion | Images | Open‑source text‑to‑image generator |
# | Midjourney | Images | Community‑driven art creation |
# | Whisper | Audio | Speech‑to‑text and voice generation |
# | AlphaFold | Protein structures | Predicts 3D protein folding from amino acid sequences |
# | Codex | Code | Generates code snippets from natural‑language descriptions |
#
# ---
#
# ## Typical Use Cases
#
# | Domain | What GenAI Does | Why It Matters |
# |--------|----------------|----------------|
# | **Content Creation** | Write articles, generate marketing copy, produce social‑media posts | Speeds up creative workflows, lowers cost |
# | **Design & Art** | Create logos, generate concept art, produce photorealistic images | Enables rapid prototyping, democratizes design |
# | **Entertainment** | Compose music, generate scripts, produce virtual characters | Enhances storytelling, offers new creative tools |
# | **Education** | Generate practice problems, explain concepts, create tutoring content | Personalizes learning, scales resources |
# | **Healthcare** | Draft medical reports, simulate drug molecules, interpret imaging | Improves diagnostics, accelerates research |
# | **Business Automation** | Draft emails, generate meeting notes, summarize documents | Boosts productivity, reduces manual effort |
#
# ---
#
# ## Key Advantages
#
# | Benefit | How GenAI Provides It |
# |---------|-----------------------|
# | **Scalability** | Once trained, a model can produce millions of outputs with minimal cost. |
# | **Customization** | Fine‑tuning lets businesses tailor content to brand voice or domain. |
# | **Speed** | Generates content in seconds, far faster than human creation. |
# | **Creativity** | Combines learned patterns in novel ways, inspiring human creators. |
#
# ---
#
# ## Important Considerations
#
# | Issue | Why It Matters | Mitigation |
# |-------|----------------|------------|
# | **Hallucinations** | Models may produce plausible but factually incorrect information. | Fact‑checking, human review, confidence scoring. |
# | **Bias & Fairness** | Training data can embed societal biases. | Diverse datasets, bias audits, post‑generation filtering. |
# | **Copyright & Ownership** | Generated content may resemble copyrighted works. | Use of open or licensed data, clear usage policies. |
# | **Misuse** | Deepfakes, disinformation, or phishing. | Robust content‑moderation, watermarking, user education. |
# | **Compute & Energy** | Training large models consumes significant resources. | Efficient architectures, model distillation, green AI initiatives. |
#
# ---
#
# ## In a Nutshell
#
# Generative AI is a set of machine‑learning models that learn to **produce** new, realistic data by capturing the underlying structure of large datasets. Whether you’re writing a novel, designing a logo, composing a song, or predicting protein structures, GenAI can generate high‑quality content quickly and at scale—while also bringing challenges that require careful oversight and responsible deployment.
