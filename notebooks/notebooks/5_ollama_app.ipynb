# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="gemma3:270m")

# %%
res = llm.invoke("Which model are you and tell me who made you? Also, how are you running on PC locally, explain")

print(res.content)
# Out:
# I am Gemma, a large language model created by the Gemma team at Google DeepMind. I'm trained on a massive dataset of text and images.
