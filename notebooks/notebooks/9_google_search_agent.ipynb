# %%
from dotenv import load_dotenv
load_dotenv

from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
search.run("Who is the CEO of Antropic?")       # Basic searching using the tool
# Out:
# "Dario Amodei: CEO of Anthropic. Dario Amodei is an American artificial intelligence researcher and entrepreneur. In 2021, he and his sister Daniela Amodei co-founded Anthropic, the company behind the large language model series Claude. Prior to that, he was the vice president of... Dario Amodei Born: 1983 (age 43 years), San Francisco, CA. Dario Amodei Net worth: 15.5 billion USD (2026). Dario Amodei Education: Stanford University, California Institute of Technology, Princeton University, and more. Dario Amodei Research interests: Machine Learning, Artificial intelligence, Reinforcement Learning, and more. Dario Amodei (born 1983) is an American artificial intelligence (AI) researcher and entrepreneur. In 2021, he and his sister Daniela Amodei co-founded Anthropic ... Experience: Anthropic · Education: Princeton University · Location: San Francisco · 334 connections on LinkedIn. View Dario Amodei's profile on LinkedIn, ... Dario Amodei is the CEO of Anthropic, a public benefit corporation dedicated to building AI systems that are steerable, interpretable and safe. Emily Chang sits down with Anthropic CEO Dario Amodei in a wide-ranging interview discussing his San Francisco roots, the race against ... Dario Amodei was a science kid. Born in San Francisco in 1983 to a Jewish mother and an Italian father, he was interested almost entirely in ... Dario Amodei called for government intervention to mitigate public risks. ByMason Leath. June 10, 2026, 9:00 PM. 8:17. Anthropic CEO Dario Amodei spoke with ... Dario Amodei is chief executive officer and co-founder of Anthropic, an artificial intelligence (AI) safety and research company working to build reliable, ... Dario Amodei is an Italian-American artificial intelligence researcher and entrepreneur, currently serving as the co-founder and CEO of Anthropic. Anthropic CEO Dario Amodei says we are 2-3 years away from superhuman AI and after having those models for a few years they could double the ..."

# %%
agent = create_agent(
    model = llm,
    tools = [search.run],
    system_prompt = "You are a search agent who can search for any answer on Google"
)

# %%
query = "Who is the CEO of OpenAI currently?" 

response = agent.invoke({"messages": [{"role": "user", "content": query}]})

# %%
print(response['messages'][-1].content)
# Out:
# The current CEO of OpenAI is **Sam Altman**.
